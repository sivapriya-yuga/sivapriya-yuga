# %% [markdown]
# <a href="https://colab.research.google.com/github/sivapriya-yuga/sivapriya-yuga/blob/main/Copy_of_Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas - Panel Data - Python Data Analysis
#
# data analysis tool
#
# cleaning - null, duplicates ,wrong entry
#
# explore
#
# manipulations

# %%
import pandas as pd

# %%
# !pip install pandas

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %% [markdown]
# pandas
#
# data series - column in table - one dimensional
#
# data frames - rows and column - table

# %%
a=[10,20,30,50]
ser=pd.Series(a)
print(ser)
# Out:
# 0    10
# 1    20
# 2    30
# 3    50
# dtype: int64

# %%
print(ser[2]) # using index
# Out:
# 30

# %%
# create own index
import pandas as pd
li=[10,20,30,40]
ser=pd.Series(li,index=["a","b","c","d"])
print(ser)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
# create own index
import pandas as pd
li=[10,20,30,40]
ser=pd.Series(li,index=["a","kk","c","z"])
print(ser)
# Out:
# a     10
# kk    20
# c     30
# z     40
# dtype: int64

# %%
# create panda series from dictionary
temperature={"chennai":44,"delhi":43,"bangalore":35}

city_temp=pd.Series(temperature)
print(city_temp)
# Out:
# chennai      44
# delhi        43
# bangalore    35
# dtype: int64

# %%
# data frame
world_data={
    'ind':{'country':'india','capital':'new delhi','population': 1428.6,'area':3288,'gdp':3730,'continent':'asia'},
    'c':{'country':'china','capital':'beijing','population': 1400.6,'area':3088,'continent':'asia'},
    'u':{'country':'usa','capital':'washington','population': 800.6,'area':1288,'gdp':1730,'continent':'america'},
    'i':{'country':'indonesia','capital':'jakarta','population': 600.6,'area':888,'gdp':930}
}
df=pd.DataFrame(world_data)
df
# Out:
#                   ind        c           u          i
# country         india    china         usa  indonesia
# capital     new delhi  beijing  washington    jakarta
# population     1428.6   1400.6       800.6      600.6
# area             3288     3088        1288        888
# gdp              3730      NaN        1730        930
# continent        asia     asia     america        NaN

# %% [markdown]
# NaN - Not a Number - missing data
#
# data cleaning

# %%
df=pd.DataFrame(world_data).T # transpose
df
# Out:
#        country     capital population  area   gdp continent
# ind      india   new delhi     1428.6  3288  3730      asia
# c        china     beijing     1400.6  3088   NaN      asia
# u          usa  washington      800.6  1288  1730   america
# i    indonesia     jakarta      600.6   888   930       NaN

# %% [markdown]
# files types
#
# csv - comma separated value
# excel
# json - javascript object notation

# %%
# create a csv file in current folder
# check in colab files
df.to_csv('world_data.csv')

# %%
# to read csv file
df=pd.read_csv('world_data.csv')

# %%
df
# Out:
#   Unnamed: 0    country     capital  population  area     gdp continent
# 0        ind      india   new delhi      1428.6  3288  3730.0      asia
# 1          c      china     beijing      1400.6  3088     NaN      asia
# 2          u        usa  washington       800.6  1288  1730.0   america
# 3          i  indonesia     jakarta       600.6   888   930.0       NaN

# %%
# to make first column as index
df=pd.read_csv('world_data.csv',index_col=0)

# %%
df
# Out:
#        country     capital  population  area     gdp continent
# ind      india   new delhi      1428.6  3288  3730.0      asia
# c        china     beijing      1400.6  3088     NaN      asia
# u          usa  washington       800.6  1288  1730.0   america
# i    indonesia     jakarta       600.6   888   930.0       NaN

# %% [markdown]
# read data from local system

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-3fe6f1f3-7b10-416f-948c-509ac464fe7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fe6f1f3-7b10-416f-948c-509ac464fe7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('loan.xlsx')
df
# Out:
#         First Name Last Name     location Loan Approval Status
# 0           ashoka   vanjare        delhi             approved
# 1            Prash      Anth      chennai             approved
# 2         Narendra     Ragam      chennai             approved
# 3          Subhani     Shaik      chennai             approved
# 4     GOUNDLA RAJU      Goud      chennai             approved
# ..             ...       ...          ...                  ...
# 75           Vijay         S         ooty             approved
# 76       Prashanth        Ve  chidambaram             approved
# 77  Nagasettypalli     Aruna  chidambaram             approved
# 78       Nagireddy         K  chidambaram             approved
# 79      Giridharan         R  chidambaram             approved
#
# [80 rows x 4 columns]

# %%
# another file from system
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-30c8a429-afba-4167-8142-73697ba51966" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30c8a429-afba-4167-8142-73697ba51966">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_h=pd.read_csv('Healthcare-Diabetes.csv')
df_h
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df_h.shape
# Out:
# (2768, 10)

# %% [markdown]
# # understanding the domain

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-46810acb-61e3-44da-996a-a22c9c14d0d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46810acb-61e3-44da-996a-a22c9c14d0d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_tit=pd.read_excel('Titanic_dataset.xlsx')
df_tit
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df_tit.shape
# Out:
# (1309, 14)

# %%
df_tit.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df_tit.size # rows x columns
# Out:
# 18326

# %%
1309*14
# Out:
# 18326

# %%
df_tit.info() # datatype,rows,columns, column name, notnull count
# object - not a numerical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df_tit.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# # quartile
#
# 25% 12 - 100 - 10
#
# 50% 4pm 1000
#
# 75% 11pm 10000 - 100

# %%
df_tit.head() # first 5 records
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df_tit.head(12)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
#
# ...

# %%
df_tit.tail() # last 5 records
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df_tit.tail(15)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1294       3         0                     Williams, Mr. Leslie    male  28.5
# 1295       3         0                      Windelov, Mr. Einar    male  21.0
# 1296       3         0                         Wirz, Mr. Albert    male  27.0
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1298       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# ...

# %%
df_tit.head(500)
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 495       2         0                Mangiavacchi, Mr. Serafino Emilio
# 496       2         0                       Matthews, Mr. William John
# 497       2         0                        Maybery, Mr. Frank Hubert
# 498       2         0                        McCrae, Mr. Arthur Gordon
# 499       2         0                        McCrie, Mr. James Matthew
#
#         sex      age  sibsp  parch       ticket      fare    cabin embarked  \
# ...

# %%
# if any data is empty, it shows true
df_tit.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
# shows null value count/total column wise
df_tit.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# to retrieve particular column
df_tit['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
df
# Out:
#         First Name Last Name     location Loan Approval Status
# 0           ashoka   vanjare        delhi             approved
# 1            Prash      Anth      chennai             approved
# 2         Narendra     Ragam      chennai             approved
# 3          Subhani     Shaik      chennai             approved
# 4     GOUNDLA RAJU      Goud      chennai             approved
# ..             ...       ...          ...                  ...
# 75           Vijay         S         ooty             approved
# 76       Prashanth        Ve  chidambaram             approved
# 77  Nagasettypalli     Aruna  chidambaram             approved
# 78       Nagireddy         K  chidambaram             approved
# 79      Giridharan         R  chidambaram             approved
#
# [80 rows x 4 columns]

# %%
df_h
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df_tit
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df_tit['fare']
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64

# %%
# filter records
df_tit[df_tit['fare']>200]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 16        1         0                           Baxter, Mr. Quigg Edmond
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 23        1         1                              Bidois, Miss. Rosalie
# 24        1         1                                  Bird, Miss. Ellen
# 35        1         1                           Bowen, Miss. Grace Scott
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 66        1         1                        Chaudanson, Miss. Victorine
# 97        1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# ...
